# %% [markdown]
# # <h1><center>An EDA of "Energy Medicine" in an Australian Psychology Practice</center></h1>

# %% [markdown]
# ![hands-4153292_1920.jpg](attachment:hands-4153292_1920.jpg)

# %% [markdown]
# ### Background
# Energy Medicine is a complimentary therapy that improves wellbeing through manipulation of body energy. It is controversial but research shows it can be helpful for stress, anxiety, mood and quality of life. Often it is used in hospitals for people with cancer and chronic pain.
#
# Energy medicine is becoming more popular in the wellness industry; however, few psychologists integrate it into their practice, mostly because it is too controversial. Psychologists are ethically bound to research their therapy, especially when they are unproven. So this niche can be targeted as long as the psychologist is applying the experimental intervention within a research context.
#
# The purpose of this analysis is twofold. Firsly, identify demographics of existing clients that can assist with planning and marketing. Secondly, clarify the type of client who receives energy medicine. This will also help with marketing and developing the practice research portfolio.

# %% [markdown]
# ### Business questions
# For the period 19/08/19 to 06/03/20:
#
# 1) What percentage of clients do not attend their first session?
#
# 2) What is the average age of clients?
#
# 3) What age should marketing target for energy healing clients?
#
# 4) What is the gender split of clients?
#
# 5) What is the average number of appointments per client?
#
# 6) What is the most common issue people seek support for?
#
# 7) What are the top 3 suburbs to target with the marketing?

# %% [markdown]
# ### Readme
# File: Clients_Aug19_March20.csv
#
# File description
# Datafile contains client data from a psychology practice in Sydney, Australia from August 2019 to March 2020.
#
# Variables include
# -ID (De-itentified ID)
#
# -Problem (Reason for Treatment)
#
# -Client Status (Active = currently engaged. "Cancelled" = the client cancelled their first booking or did not show)
# -Age
#
# -Gender (0 = female; 1= male)
#
# -Suburb
#
# -Source (referral source)
#
# -Healing (whether the client has received energy medicine)
#
# -Appointments (number of appointments from August 2019 to March 2020)

# %% [markdown]
# # Establishing the workspace and importing the dataframe

# %%
#Import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

# %%
#Read the csv file
client = pd.read_csv('Client_Aug_Mar.csv')
client.head()
# Out:
#          ID        Problem                Type Client Status  Gender   Age  \
# 0  100kieAl    Personality  Private (Standard)        Active  Female  33.0
# 1  101kosPe    Personality  Private (Standard)        Active    Male  43.0
# 2  102lanHe  Relationships   Agency (Standard)        Active  Female  33.0
# 3  103lanJa            NaN                 NaN     Cancelled     NaN   NaN
# 4  104lanKe  Substance use   Agency (Standard)        Active  Female  64.0
#
#      Source            Suburb  Source.1 Healing  Appointments
# 0  Internet             Menai  Internet      No           1.0
# 1  Internet        Yarrawarra  Internet      No           7.0
# 2    Agency  Woronora Heights    Agency      No          11.0
# 3       NaN               NaN       NaN     NaN           NaN
# 4  Internet         Bomaderry  Internet      No           1.0

# %%
#Check distributions of age and appointments are correct.
client.describe()
# Out:
#               Age  Appointments
# count  173.000000    204.000000
# mean    37.994220      2.877451
# std     12.023474      3.008965
# min     15.000000      1.000000
# 25%     30.000000      1.000000
# 50%     37.000000      1.000000
# 75%     46.000000      4.000000
# max     70.000000     18.000000

# %% [markdown]
# # Data Munging - detecting and removing redundant columns

# %%
#Calling the '.head()' command shows there is a duplicate column "Source.1" that needs removing.
del client['Source.1']

# %%
# Source.1 has been successfully removed.
client.columns
# Out:
# Index(['ID', 'Problem', 'Type', 'Client Status', 'Gender', 'Age', 'Source',
#        'Suburb', 'Healing', 'Appointments'],
#       dtype='object')

# %%
#Screening for duplicate clients. There is one duplicate row.
dup_clients=client[client.duplicated()]
dup_clients
# Out:
#          ID        Problem          Type Client Status  Gender   Age  \
# 229  9amsAl  Relationships  Not Assigned        Active  Female  30.0
#
#         Source     Suburb Healing  Appointments
# 229  Colleague  Gymea Bay      No           1.0

# %%
#Viewing both duplicated rows to ensure they are the same.
client.loc[client.ID.duplicated(keep=False)]
# Out:
#          ID        Problem          Type Client Status  Gender   Age  \
# 228  9amsAl  Relationships  Not Assigned        Active  Female  30.0
# 229  9amsAl  Relationships  Not Assigned        Active  Female  30.0
#
#         Source     Suburb Healing  Appointments
# 228  Colleague  Gymea Bay      No           1.0
# 229  Colleague  Gymea Bay      No           1.0

# %%
#Row 229 needs to be dropped
discrete_clients = client.drop_duplicates()

# %%
#There are now no duplicates.
discrete_clients.loc[discrete_clients.ID.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [ID, Problem, Type, Client Status, Gender, Age, Source, Suburb, Healing, Appointments]
# Index: []

# %% [markdown]
# # Exploring missing data

# %%
#View all 228 rows
pd.set_option("max_rows", None)
discrete_clients
# Out:
#            ID               Problem                     Type Client Status  \
# 0    100kieAl           Personality       Private (Standard)        Active
# 1    101kosPe           Personality       Private (Standard)        Active
# 2    102lanHe         Relationships        Agency (Standard)        Active
# 3    103lanJa                   NaN                      NaN     Cancelled
# 4    104lanKe         Substance use        Agency (Standard)        Active
# 5    105lasAn         Relationships  Private (complementary)        Active
# 6    106lenAl                Stress  Private (complementary)        Active
# 7    107letJa           Personality  Private (complementary)        Active
# 8    108leyAn               Anxiety       Private (Standard)        Active
# 9    109leyBe                   NaN                      NaN     Cancelled
# 10    10amsKa           Personality        Agency (Standard)        Active
# 11   110leyDa         Relationships       Private (Standard)        Active
# 12   111leyJo                   NaN                      NaN     Cancelled
# 13   112lieKa         Relationships  Private (complementary)        Active
# 14   113lieRy           Personality         Inspirit - (WDO)        Active
# 15   114ljaLu                Stress  Private (complementary)        Active
# 16   115lloMa  Obsessive-Compulsive  Private (complementary)        Active
# 17   116llyJa         Relationships       Private (Standard)        Active
# 18   117lmeSi         Relationships        Agency (Standard)        Active
# 19   118losCa               Anxiety  Private (complementary)        Active
# 20   119losJa         Relationships       Private (Standard)        Active
# 21    11amsLa                   NaN                      NaN     Cancelled
# 22   120manCa         Substance use  Private (complementary)        Active
# 23   121manDa                Autism       Private (Standard)        Active
# 24   122manTa         Relationships               EAP Client        Active
# 25   123marMa         Relationships  Private (complementary)        Active
# 26   124masBe         Relationships             Not Assigned        Active
# 27   125mazSa         Relationships       Private (Standard)        Active
# 28   126mbeSh               Anxiety  Private (complementary)        Active
# 29   127mecSa               Anxiety  Private (complementary)        Active
# 30   128merBr         Relationships       Private (Standard)        Active
# 31   129mesGe                   NaN                      NaN     Cancelled
# 32    12amsPa         Relationships  Private (complementary)        Active
# 33   130mosSh         Relationships  Private (complementary)        Active
# 34   131nemCa           Supervision              Supervision        Active
# 35   132nerDa         Relationships       Private (Standard)        Active
# 36   133nerTa         Substance use  Private (complementary)        Active
# 37   134nesDo               Anxiety             Not Assigned        Active
# 38   135nesKa               Anxiety               EAP Client        Active
# 39   136nesKy                   NaN                      NaN     Cancelled
# 40   137nesSa                   NaN                      NaN     Cancelled
# 41   138nesSh                   NaN                      NaN     Cancelled
# 42   139neyCh         Mood disorder  Private (complementary)        Active
# 43    13andJo         Relationships               EAP Client        Active
# 44   140nicVe               Anxiety             Not Assigned        Active
# 45   141nieMe                   NaN                      NaN     Cancelled
# 46   142nisMa                Stress        Agency (Standard)        Active
# 47   143nkiNi         Relationships  Private (complementary)        Active
# 48   144nkoVa         Relationships       Private (Standard)        Active
# 49   145nryAl         Substance use  Private (complementary)        Active
# 50   146ntiTa               Anxiety  Private (complementary)        Active
# 51   147ntzEm                   NaN                      NaN     Cancelled
# 52   148ollMe         Relationships       Private (Standard)        Active
# 53   149ollMe  Obsessive-Compulsive  Private (complementary)        Active
# 54    14andMa               Anxiety       Private (Standard)        Active
# 55   150oneRu               Anxiety  Private (complementary)        Active
# 56   151ongSa               Anxiety       Private (Standard)        Active
# 57   152oodCl         Mood disorder   Agency (complementary)        Active
# 58   153oodMi         Substance use  Private (complementary)        Active
# 59   154ordBe            Adjustment               EAP Client        Active
# 60   155oseDa           Personality       Private (Standard)        Active
# 61   156ottLo                Stress       Private (Standard)        Active
# 62   157ottsc                   NaN                      NaN     Cancelled
# 63   158ovaEk         Relationships  Private (complementary)        Active
# 64   159oweAm                Stress               EAP Client        Active
# 65    15aneMa                Trauma  Private (complementary)        Active
# 66   160ranZo         Relationships       Private (Standard)        Active
# 67   161raySc         Relationships       Private (Standard)        Active
# 68   162renCh         Relationships       Private (Standard)        Active
# 69   163renPe           Personality               EAP Client        Active
# 70   164resNa         Relationships  Private (complementary)        Active
# 71   165reySu            Adjustment       Private (Standard)        Active
# 72   166rgeKa         Relationships  Private (complementary)        Active
# 73   167ricSt               Anxiety             Not Assigned        Active
# 74   168rieBe         Relationships       Private (Standard)        Active
# 75   169risKi         Relationships               EAP Client        Active
# 76    16angCh         Substance use             Not Assigned        Active
# 77   170risLi               Anxiety  Private (complementary)        Active
# 78   171risLu                   NaN                      NaN     Cancelled
# 79   172rovMa                   NaN                      NaN     Cancelled
# 80   173rpeBe  Obsessive-Compulsive               EAP Client        Active
# 81   174rryDa         Relationships        Agency (Standard)        Active
# 82   175rsiMa           Personality        Agency (Standard)        Active
# 83   176ruzNa         Relationships        Agency (Standard)        Active
# 84   177salRo           Personality               EAP Client        Active
# 85   178senBe                   NaN                      NaN     Cancelled
# 86   179skaIv               Anxiety        Agency (Standard)        Active
# 87    17angSe         Relationships        Agency (Standard)        Active
# 88   180skiSa               Anxiety  Private (complementary)        Active
# 89   181sonDa         Mood disorder       Private (Standard)        Active
# 90   182sonEl               Anxiety  Private (complementary)        Active
# 91   183sonJe               Anxiety  Private (complementary)        Active
# 92   184sonJo            Adjustment  Private (complementary)        Active
# 93   185sonLo         Relationships  Private (complementary)        Active
# 94   186sonMa         Relationships  Private (complementary)        Active
# 95   187sonMa         Relationships  Private (complementary)        Active
# 96   188sonSt         Relationships             Not Assigned        Active
# 97   189ssiAn         Mood disorder  Private (complementary)        Active
# 98    18angXu                Stress             Not Assigned        Active
# 99   190tanSe               Anxiety   Agency (complementary)        Active
# 100  191terJa                   NaN                      NaN     Cancelled
# 101  192thyCl               Anxiety  Private (complementary)        Active
# 102  193thyLu  Obsessive-Compulsive  Private (complementary)        Active
# 103  194tieSi           Personality               EAP Client        Active
# 104  195tisEf         Relationships             Not Assigned        Active
# 105  196tonAn                Trauma       Private (Standard)        Active
# 106  197tonBe         Relationships  Private (complementary)        Active
# 107  198tonEl         Substance use  Private (complementary)        Active
# 108  199tonHe           Personality  Private (complementary)        Active
# 109   19ansSa           Supervision             Not Assigned        Active
# 110    1achMi  Obsessive-Compulsive       Private (Standard)        Active
# 111  200tonKe            Adjustment       Private (Standard)        Active
# 112  201tonSa           Personality  Private (complementary)        Active
# 113  202uceJu                Stress               EAP Client        Active
# 114  203ummSt                Health  Private (complementary)        Active
# 115  204untRi           Personality  Private (complementary)        Active
# 116  205uryJa               Anxiety               EAP Client        Active
# 117  206useNa         Relationships       Private (Standard)        Active
# 118  207uttSu               Anxiety       Private (Standard)        Active
# 119  208uysAd                   NaN                      NaN     Cancelled
# 120  209vaiMi               Anxiety  Private (complementary)        Active
# 121   20antLu         Mood disorder      Inspirit (Standard)        Active
# 122  210veyZa                Stress       Private (Standard)        Active
# 123  211vicMa               Anxiety       Private (Standard)        Active
# 124  212visCo               Anxiety       Private (Standard)        Active
# 125  213visGr            Adjustment  Private (complementary)        Active
# 126  214walNi           Personality  Private (complementary)        Active
# 127  215wenJa         Substance use  Private (complementary)        Active
# 128  216wenPa               Anxiety               EAP Client        Active
# 129  217XieAl               Anxiety       Private (Standard)        Active
# 130  218yahTi         Relationships  Private (complementary)        Active
# 131  219zarMe         Relationships  Private (complementary)        Active
# 132   21antPa         Relationships       Private (Standard)        Active
# 133  220zasDa               Anxiety  Private (complementary)        Active
# 134  221eldDa                Stress  Private (complementary)        Active
# 135  222phyDr                Stress  Private (complementary)        Active
# 136  223loeBe                Stress  Private (complementary)        Active
# 137  224kieFi         Relationships  Private (complementary)        Active
# 138  225ikeGa         Relationships  Private (complementary)        Active
# 139  226dasHe               Anxiety  Private (complementary)        Active
# 140  227ockMi         Mood disorder  Private (complementary)        Active
# 141  228allNi         Relationships  Private (complementary)        Active
# 142  229FooSa           Personality  Private (complementary)        Active
# 143   22araLe                Trauma  Private (complementary)        Active
# 144   23ardAd               Anxiety  Private (complementary)        Active
# 145   24ardAl               Anxiety             Not Assigned        Active
# 146   25ardCa               Anxiety  Private (complementary)        Active
# 147   26ardMa         Mood disorder       Private (Standard)        Active
# 148   27ariAn                Stress        Agency (Standard)        Active
# 149   28arrZo         Relationships  Private (complementary)        Active
# 150   29attAn         Mood disorder   Agency (complementary)        Active
# 151    2acsMa                Stress               EAP Client        Active
# 152   30besMa           Personality   Agency (complementary)        Active
# 153   31bleLo                Stress               EAP Client        Active
# 154   32cerCe          Not Assigned  Private (complementary)        Active
# 155   33cicLj                Trauma  Private (complementary)        Active
# 156   34cicNu                Stress        Agency (Standard)        Active
# 157   35ckyJo         Relationships  Private (complementary)        Active
# 158   36CoxAn         Relationships  Private (complementary)        Active
# 159   37CoxAn         Relationships       Private (Standard)        Active
# 160   38delBa         Mood disorder       Private (Standard)        Active
# 161   39delGr           Personality       Private (Standard)        Active
# 162    3ainNa         Substance use       Private (Standard)        Active
# 163   40delJe                   NaN                      NaN     Cancelled
# 164   41derSa                Trauma       Private (Standard)        Active
# 165   42dgeLi               Anxiety       Private (Standard)        Active
# 166   43edaSa           Personality       Private (Standard)        Active
# 167   44eerJa  Obsessive-Compulsive       Private (Standard)        Active
# 168   45eidDa                Autism       Private (Standard)        Active
# 169   46eilBr                Stress  Private (complementary)        Active
# 170   47eilSh         Relationships       Private (Standard)        Active
# 171   48eldCh           Personality  Private (complementary)        Active
# 172   49eldNi                Health  Private (complementary)        Active
# 173    4akeCh         Relationships       Private (Standard)        Active
# 174   50eldNi                Health  Private (complementary)        Active
# 175   51ellCa            Adjustment               EAP Client        Active
# 176   52ellIa         Substance use  Private (complementary)        Active
# 177   53ellLu           Personality  Private (complementary)        Active
# 178   54ellSi         Substance use   Agency (complementary)        Active
# 179   55ennGl                   NaN                      NaN     Cancelled
# 180   56ensJe                Trauma             Not Assigned        Active
# 181   57eonPa           Personality       Private (Standard)        Active
# 182   58ersBe                Trauma   Agency (complementary)        Active
# 183   59ersNi           Personality  Private (complementary)        Active
# 184    5akeMa         Mood disorder       Private (Standard)        Active
# 185   60ertJa                   NaN                      NaN     Cancelled
# 186   61essCa           Personality  Private (complementary)        Active
# 187   62ettMa           Personality  Private (complementary)        Active
# 188   63fesAn         Relationships       Private (Standard)        Active
# 189   64ganSe                   NaN                      NaN     Cancelled
# 190   65gorMa         Substance use  Private (complementary)        Active
# 191   66gorPa                   NaN                      NaN     Cancelled
# 192   67gosNa                   NaN                      NaN     Cancelled
# 193   68halCr         Relationships             Not Assigned        Active
# 194   69hamAl         Relationships  Private (complementary)        Active
# 195    6aldBr            Adjustment        Agency (Standard)        Active
# 196   70hamGe         Relationships  Private (complementary)        Active
# 197   71hamMo                Trauma             Not Assigned        Active
# 198   72hanCa               Anxiety       Private (Standard)        Active
# 199   73herRy         Substance use  Private (complementary)        Active
# 200   74ianBe           Personality       Private (Standard)        Active
# 201   75iarJo           Personality       Private (Standard)        Active
# 202   76ickMa                   NaN                      NaN     Cancelled
# 203   77inaMa           Personality        Agency (Standard)        Active
# 204   78ingJo         Substance use   Agency (complementary)        Active
# 205   79ingEl         Relationships       Private (Standard)        Active
# 206    7allBe           Personality       Private (Standard)        Active
# 207   80ingNa                   NaN                      NaN     Cancelled
# 208   81ingNi         Relationships       Private (Standard)        Active
# 209   82ingPe         Relationships       Private (Standard)        Active
# 210   83ingSa                Stress  Private (complementary)        Active
# 211   84iniMa         Relationships   Agency (complementary)        Active
# 212   85inkSa         Substance use             Not Assigned        Active
# 213   86insDa               Anxiety       Private (Standard)        Active
# 214   87iorNa         Substance use  Private (complementary)        Active
# 215   88iraPh                Stress  Private (complementary)        Active
# 216   89ireJe           Personality       Private (Standard)        Active
# 217    8alyKa                   NaN                      NaN     Cancelled
# 218   90irkTr                Health  Private (complementary)        Active
# 219   91iseLo               Anxiety       Private (Standard)        Active
# 220   92issJa                Stress  Private (complementary)        Active
# 221   93iteNa         Relationships        Agency (Standard)        Active
# 222   94ithBr                   NaN                      NaN     Cancelled
# 223   95ithDe         Relationships        Agency (Standard)        Active
# 224   96ithJe               Anxiety  Private (complementary)        Active
# 225   97kerDa          Not Assigned  Private (complementary)        Active
# 226   98kerJu         Substance use       Private (Standard)        Active
# 227   99kerSt               Anxiety  Private (complementary)        Active
# 228    9amsAl         Relationships             Not Assigned        Active
#
#           Gender   Age           Source             Suburb Healing  \
# 0         Female  33.0         Internet              Menai      No
# 1           Male  43.0         Internet         Yarrawarra      No
# 2         Female  33.0           Agency   Woronora Heights      No
# 3            NaN   NaN              NaN                NaN     NaN
# 4         Female  64.0         Internet          Bomaderry      No
# 5           Male   NaN         Internet        Grays Point      No
# 6         Female  25.0    Word of mouth         Woolooware      No
# 7         Female  37.0               GP        Helensburgh      No
# 8           Male  47.0         Internet            Kareela      No
# 9            NaN   NaN              NaN                NaN     NaN
# 10          Male  38.0  Previous client                NaN      No
# 11          Male   NaN           Agency         Sutherland      No
# 12           NaN   NaN              NaN                NaN     NaN
# 13        Female  31.0         Internet        Helensburgh      No
# 14          Male  21.0              WDO   Greenhills Beach      No
# 15          Male  44.0    Word of mouth          Gymea Bay      No
# 16        Female  29.0         Internet         Sutherland     Yes
# 17        Female  53.0         Internet           Sylvania      No
# 18          Male  38.0           Agency               Como      No
# 19        Female  23.0         Internet           Illawong      No
# 20        Female  49.0         Internet  Brighten Le Sands      No
# 21           NaN   NaN              NaN                NaN     NaN
# 22        Female   NaN              NaN                NaN      No
# 23        Female   NaN  Previous client        Camera Park      No
# 24        Female   NaN              EAP            Miranda      No
# 25        Female  36.0        Colleague            Montery      No
# 26        Female  39.0              NaN         Sutherland      No
# 27        Female  36.0        Colleague              Gymea      No
# 28        Female  26.0         Internet          Heathcote     Yes
# 29        Female  22.0         Internet          Caringbah      No
# 30        Female  36.0         Internet              Menai      No
# 31           NaN   NaN              NaN                NaN     NaN
# 32          Male  46.0               GP           Engadine      No
# 33          Male  43.0        Colleague         Manly Vale      No
# 34        Female   NaN              NaN            Lakemba      No
# 35          Male  49.0         Internet           Engadine      No
# 36        Female   NaN         Internet           Cronulla      No
# 37        Female  51.0              NaN           Cronulla      No
# 38        Female   NaN              EAP           Buraneer      No
# 39           NaN   NaN              NaN                NaN     NaN
# 40           NaN   NaN              NaN                NaN     NaN
# 41           NaN   NaN              NaN                NaN     NaN
# 42          Male  31.0         Internet              Gymea      No
# 43        Female   NaN              EAP         Sutherland      No
# 44        Female   NaN              NaN                NaN      No
# 45           NaN   NaN              NaN                NaN     NaN
# 46        Female  59.0           Agency  Brighton Le Sands      No
# 47          Male  27.0              NaN      Alfords Point      No
# 48          Male   NaN              NaN                NaN      No
# 49        Female  21.0               GP              Gymea      No
# 50        Female  25.0    Word of mouth    Sylvania Waters      No
# 51           NaN   NaN              NaN                NaN     NaN
# 52        Female  34.0               GP             Bangor     Yes
# 53        Female  40.0               GP             Bangor     Yes
# 54        Female  28.0         Internet       Barden Ridge      No
# 55          Male  18.0         Internet           Coledale      No
# 56          Male  31.0               GP         Blakehurst      No
# 57          Male  46.0           Agency            Jannali      No
# 58          Male  46.0         Internet              Gymea     Yes
# 59        Female  56.0              EAP       Barden Ridge      No
# 60          Male  35.0         Internet           Sylvania      No
# 61        Female   NaN              NaN                NaN      No
# 62           NaN   NaN              NaN                NaN     NaN
# 63        Female  35.0         Internet        Kogarah Bay      No
# 64        Female   NaN              NaN            Miranda      No
# 65          Male  47.0    Word of mouth          Heathcote      No
# 66        Female  41.0               GP           Kirrawee      No
# 67          Male  53.0         Internet              Gymea      No
# 68          Male  38.0               GP     Connells Point      No
# 69        Female  21.0              NaN          Caringbah      No
# 70        Female  34.0    Word of mouth           Milperra      No
# 71        Female  58.0         Internet            Padstow      No
# 72        Female   NaN              NaN                NaN      No
# 73        Female  29.0         Internet              Menai     Yes
# 74          Male  39.0         Internet   Woronora Heights      No
# 75        Female   NaN              EAP                NaN      No
# 76        Female  60.0              NaN                NaN      No
# 77        Female  38.0        Colleague        Taren Point     Yes
# 78           NaN   NaN              NaN                NaN     NaN
# 79           NaN   NaN              NaN                NaN     NaN
# 80          Male   NaN              EAP         Sutherland      No
# 81        Female  43.0           Agency          Caringbah      No
# 82          Male  31.0           Agency              Gymea      No
# 83        Female  40.0           Agency      Voyager Point      No
# 84        Female  32.0              EAP            Allawah      No
# 85           NaN   NaN              NaN                NaN     NaN
# 86        Female  17.0           Agency          Penshurst      No
# 87        Female  36.0              NaN         Sutherland      No
# 88        Female   NaN         Internet   Woronora Heights     Yes
# 89          Male  55.0               GP             Bangor      No
# 90          Male  28.0               GP              Bulli      No
# 91        Female  24.0    Word of mouth                NaN      No
# 92          Male  37.0         Internet            Padstow     Yes
# 93        Female  43.0         Internet          Worronora     Yes
# 94          Male   NaN         Internet           Engadine      No
# 95          Male  37.0         Internet           Engadine      No
# 96          Male  44.0         Internet            Kareela      No
# 97          Male  28.0         Internet            Jannali      No
# 98          Male  46.0              NaN           Eastwood     Yes
# 99        Female  29.0           Agency               Como      No
# 100          NaN   NaN              NaN                NaN     NaN
# 101       Female  31.0         Internet           Lewisham     Yes
# 102         Male  18.0         Internet           Kirrawee      No
# 103         Male   NaN              EAP        Grays Point     Yes
# 104       Female  53.0              NaN                NaN      No
# 105       Female  60.0         Referral   Woronora Heights      No
# 106         Male  19.0         Internet           Woronora      No
# 107       Female  33.0         Internet           Kirrawee     Yes
# 108       Female  49.0    Word of mouth           Woronora      No
# 109       Female   NaN              NaN                NaN      No
# 110         Male  37.0               GP         Woolooware      No
# 111         Male  38.0               GP          Mangerton     Yes
# 112         Male  19.0         Internet           Kirrawee      No
# 113  Unspecified   NaN              EAP                NaN      No
# 114         Male  65.0         Internet               Como      No
# 115         Male  58.0         Internet           Sylvania      No
# 116       Female   NaN              EAP                NaN     Yes
# 117         Male  31.0         Internet              Menai      No
# 118       Female  70.0         Referral              Menai      No
# 119          NaN   NaN              NaN                NaN     NaN
# 120       Female   NaN               GP       Barden Ridge      No
# 121         Male  39.0         Internet      Alfords Point      No
# 122         Male  26.0         Internet           Woronora      No
# 123       Female  18.0    Word of mouth            Horsley      No
# 124         Male  26.0           Agency             Bangor      No
# 125         Male  33.0         Referral        Helensburgh      No
# 126         Male  33.0         Internet        Helensburgh      No
# 127       Female  31.0         Internet         Sutherland      No
# 128       Female   NaN              EAP          Gymea Bay      No
# 129       Female  21.0         Internet               Como      No
# 130       Female  35.0         Internet             Bangor      No
# 131       Female  38.0        Colleague            Figtree      No
# 132         Male   NaN              NaN                NaN      No
# 133         Male  39.0    Word of mouth               Como      No
# 134       Female  35.0  Previous client           Engadine     Yes
# 135         Male  40.0         Internet          Caringbah     Yes
# 136         Male  38.0              NaN      Alfords Point     Yes
# 137       Female  52.0         Internet         Wollongong     Yes
# 138       Female  36.0         Internet              Menai     Yes
# 139       Female  42.0         Internet         Sutherland     Yes
# 140         Male  62.0               GP         Sutherland     Yes
# 141       Female  35.0         Internet          Caringbah     Yes
# 142       Female  30.0         Referral         Sutherland     Yes
# 143       Female  53.0        Colleague          Roseville     Yes
# 144         Male  46.0               GP              Gymea      No
# 145         Male   NaN              NaN                NaN      No
# 146         Male  26.0         Internet         Sutherland     Yes
# 147         Male  47.0               GP           Illawong      No
# 148       Female  50.0           Agency          Yowie Bay      No
# 149       Female  24.0         Internet           Engadine      No
# 150         Male  37.0         Internet      Kembla Grange      No
# 151         Male  61.0         Internet         Bonnet Bay     Yes
# 152         Male  44.0           Agency      Stanwell Tops     Yes
# 153       Female   NaN              NaN                NaN      No
# 154         Male  43.0         Internet          Caringbah      No
# 155       Female   NaN    Word of mouth          Liverpool      No
# 156       Female  45.0              NaN           Cronulla      No
# 157         Male  42.0              NaN         Oyster Bay      No
# 158         Male  52.0         Internet           Engadine      No
# 159         Male  48.0         Internet           Engadine      No
# 160         Male  33.0         Internet         Sutherland     Yes
# 161         Male  52.0  Previous client            Kareela      No
# 162         Male  43.0         Internet          Caringbah      No
# 163          NaN   NaN              NaN                NaN     NaN
# 164       Female  56.0    Word of mouth          Caringbah      No
# 165         Male  33.0               GP           Engadine      No
# 166       Female  21.0         Referral              Menai      No
# 167         Male  18.0         Internet               Como      No
# 168         Male  47.0         Internet         Sutherland      No
# 169       Female  45.0        Colleague           Bundeena      No
# 170         Male  44.0         Internet           Bundeena      No
# 171       Female  27.0         Internet              Menai      No
# 172       Female  45.0    Word of mouth           Horseley      No
# 173         Male  69.0         Internet           Kirrawee      No
# 174       Female  15.0    Word of mouth           Horseley      No
# 175       Female   NaN              EAP           Engadine      No
# 176         Male  42.0               GP         Oyster Bay      No
# 177         Male  31.0         Internet        Lilli Pilli      No
# 178       Female  27.0           Agency         Sans Souci      No
# 179          NaN   NaN              NaN                NaN     NaN
# 180       Female  52.0              NaN           Cronulla      No
# 181         Male  69.0         Internet             Bangor      No
# 182       Female  64.0           Agency      Beverly Hills     Yes
# 183       Female  43.0           Agency          Caringbah      No
# 184         Male  44.0               GP         Sutherland      No
# 185          NaN   NaN              NaN                NaN     NaN
# 186         Male  47.0         Internet          Caringbah      No
# 187       Female   NaN              NaN                NaN      No
# 188         Male  33.0         Internet       Barden Ridge      No
# 189          NaN   NaN              NaN                NaN     NaN
# 190       Female  45.0              WDO           Engadine     Yes
# 191          NaN   NaN              NaN                NaN     NaN
# 192          NaN   NaN              NaN                NaN     NaN
# 193       Female  37.0              NaN    Caringbah South      No
# 194       Female  33.0         Internet           Sylvania      No
# 195         Male  41.0           Agency            Belambi      No
# 196       Female  25.0         Internet                NaN      No
# 197         Male   NaN              NaN                NaN      No
# 198         Male  19.0         Internet         Sutherland      No
# 199         Male  25.0         Internet           Illawong      No
# 200       Female  30.0         Internet         Sutherland      No
# 201       Female  35.0               GP         Sutherland      No
# 202          NaN   NaN              NaN                NaN     NaN
# 203         Male  36.0           Agency          Caringbah      No
# 204         Male  51.0           Agency             Bangor      No
# 205       Female  43.0         Internet    Caringbah South      No
# 206         Male  28.0         Internet           Cronulla      No
# 207          NaN   NaN              NaN                NaN     NaN
# 208         Male  31.0         Internet           Woronora      No
# 209         Male  35.0         Internet          Caringbah      No
# 210       Female  37.0         Internet      Voyager Point     Yes
# 211       Female  40.0           Agency        West Hoxton      No
# 212         Male  29.0              NaN           Cronulla      No
# 213         Male  19.0         Internet             Oatley      No
# 214         Male  23.0         Internet         Sutherland      No
# 215       Female  21.0         Internet              Gymea     Yes
# 216       Female  21.0         Internet           Engadine      No
# 217          NaN   NaN              NaN                NaN     NaN
# 218         Male  49.0               GP            Carlton      No
# 219       Female  20.0         Internet             Bangor      No
# 220       Female  39.0         Internet          San Souci      No
# 221       Female  32.0           Agency            Padstow      No
# 222          NaN   NaN              NaN                NaN     NaN
# 223       Female  51.0              NaN        Helensburgh      No
# 224       Female  25.0         Internet               Como     Yes
# 225         Male  50.0         Internet           Cronulla      No
# 226         Male  38.0         Internet     Mount Warrigal      No
# 227         Male  45.0         Internet               Como      No
# 228       Female  30.0        Colleague          Gymea Bay      No
#
#      Appointments
# 0             1.0
# 1             7.0
# 2            11.0
# 3             NaN
# 4             1.0
# 5             2.0
# 6             1.0
# 7             5.0
# 8             2.0
# 9             NaN
# 10            4.0
# 11            1.0
# 12            NaN
# 13            1.0
# 14            1.0
# 15            1.0
# 16           11.0
# 17            1.0
# 18            6.0
# 19            1.0
# 20           18.0
# 21            NaN
# 22            1.0
# 23            2.0
# 24            4.0
# 25            1.0
# 26            1.0
# 27            1.0
# 28            7.0
# 29            1.0
# 30            2.0
# 31            NaN
# 32            1.0
# 33            1.0
# 34            1.0
# 35            1.0
# 36            1.0
# 37            1.0
# 38            2.0
# 39            NaN
# 40            NaN
# 41            NaN
# 42            4.0
# 43            5.0
# 44            1.0
# 45            NaN
# 46            1.0
# 47            2.0
# 48            1.0
# 49            1.0
# 50            1.0
# 51            NaN
# 52            3.0
# 53            3.0
# 54            1.0
# 55            1.0
# 56            5.0
# 57            2.0
# 58            4.0
# 59            3.0
# 60            3.0
# 61            1.0
# 62            NaN
# 63            1.0
# 64            1.0
# 65            6.0
# 66            1.0
# 67            6.0
# 68            1.0
# 69            1.0
# 70            2.0
# 71            5.0
# 72            1.0
# 73            5.0
# 74            1.0
# 75            3.0
# 76            1.0
# 77            2.0
# 78            NaN
# 79            NaN
# 80            5.0
# 81            2.0
# 82           12.0
# 83            2.0
# 84            1.0
# 85            NaN
# 86            1.0
# 87            1.0
# 88            5.0
# 89            2.0
# 90            1.0
# 91            3.0
# 92            6.0
# 93            5.0
# 94            2.0
# 95            2.0
# 96            1.0
# 97            1.0
# 98            1.0
# 99            3.0
# 100           NaN
# 101           2.0
# 102           1.0
# 103           2.0
# 104           1.0
# 105           1.0
# 106           3.0
# 107           2.0
# 108           3.0
# 109           2.0
# 110           1.0
# 111           9.0
# 112           2.0
# 113           3.0
# 114           1.0
# 115           1.0
# 116           4.0
# 117           1.0
# 118           1.0
# 119           NaN
# 120           1.0
# 121           4.0
# 122           1.0
# 123           1.0
# 124           1.0
# 125           2.0
# 126           5.0
# 127           2.0
# 128           1.0
# 129           1.0
# 130           2.0
# 131           9.0
# 132           1.0
# 133           2.0
# 134           6.0
# 135           8.0
# 136           4.0
# 137           2.0
# 138           2.0
# 139           7.0
# 140          11.0
# 141           1.0
# 142           7.0
# 143           3.0
# 144           1.0
# 145           1.0
# 146           2.0
# 147           4.0
# 148           1.0
# 149           1.0
# 150           1.0
# 151           5.0
# 152           1.0
# 153           1.0
# 154           1.0
# 155           7.0
# 156           4.0
# 157           1.0
# 158           5.0
# 159           5.0
# 160          16.0
# 161           4.0
# 162           1.0
# 163           NaN
# 164           3.0
# 165           1.0
# 166           1.0
# 167           2.0
# 168           1.0
# 169           1.0
# 170           7.0
# 171           5.0
# 172           8.0
# 173           3.0
# 174           8.0
# 175           3.0
# 176           1.0
# 177           1.0
# 178           1.0
# 179           NaN
# 180           1.0
# 181           1.0
# 182          17.0
# 183           4.0
# 184           3.0
# 185           NaN
# 186           1.0
# 187           1.0
# 188           1.0
# 189           NaN
# 190           6.0
# 191           NaN
# 192           NaN
# 193           1.0
# 194           1.0
# 195           1.0
# 196           1.0
# 197           1.0
# 198           9.0
# 199           1.0
# 200           1.0
# 201           1.0
# 202           NaN
# 203           4.0
# 204          10.0
# 205           1.0
# 206           1.0
# 207           NaN
# 208           1.0
# 209           4.0
# 210           1.0
# 211           1.0
# 212           1.0
# 213           2.0
# 214           1.0
# 215           6.0
# 216          12.0
# 217           NaN
# 218           1.0
# 219           3.0
# 220           1.0
# 221           3.0
# 222           NaN
# 223           1.0
# 224           4.0
# 225           1.0
# 226           3.0
# 227           1.0
# 228           1.0

# %%
#The structure of the dataframe is correct. But I see lots of NaN and especially for clients with a status of 'cancelled'.
#How many NaN values are there? 
discrete_clients.isnull().sum().sum()
# Out:
# 286

# %%
#Locating the missing values.
discrete_clients.isnull().sum()
# Out:
# ID                0
# Problem          26
# Type             26
# Client Status     0
# Gender           26
# Age              57
# Source           54
# Suburb           45
# Healing          26
# Appointments     26
# dtype: int64

# %%
#Missing values are widely distributed. Except for ID and Client Status. Examine clients wih status of cancelled. Firstly determine how many cancelled clients there are.
status=discrete_clients.groupby(['Client Status']).count()
status
# Out:
#                 ID  Problem  Type  Gender  Age  Source  Suburb  Healing  \
# Client Status
# Active         203      203   203     203  172     175     184      203
# Cancelled       26        0     0       0    0       0       0        0
#
#                Appointments
# Client Status
# Active                  203
# Cancelled                 0

# %% [markdown]
# #### Summary of missing values
# There are missing values in Age, Source and Suburb for the 'Active' clients. This will be due to human error and missing information from referring agencies.
#
# Cancelled clients have missing values in every field which is understandable because they never attend the practice and so we don't have their data.
#
# Cancelled clients must be dropped from the dataframe; however, before that is done the percentage of clients making appointments but not attending must be determined. This was a business question.

# %% [markdown]
# # Q1). What percentage of people do not attend their appointment?

# %%
status = discrete_clients['Client Status']
counts = status.value_counts()
percent100 = status.value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
pd.DataFrame({'counts': counts, '%': percent100})
# Out:
#            counts      %
# Active        203  88.6%
# Cancelled      26  11.4%

# %% [markdown]
# #### <b>Summary of cancellation rates</b>
# From August 2019 to March 2020 there were 26 people who booked a consultation but did not attend. This is <b>11.4%</b> of total bookings for the period. No further demographics are available for these people because they never arrived at the practice.
#
# <b>Recommendations:</b> If I can get more data from people when booking their appointment I may be able to clarify the demographics that are associated with non-attendance.

# %% [markdown]
# # Managing missing data
# #### Now back to the issue of large amounts of missing data in the 'Cancelled' clients. Its time to remove them from the dataframe.

# %%
# Remove 'Cancelled' clients from the dataframe. 
active_clients = ['Active']
discrete_clients['Client Status'].isin(active_clients)
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9      False
# 10      True
# 11      True
# 12     False
# 13      True
# 14      True
# 15      True
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21     False
# 22      True
# 23      True
# 24      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
# 30      True
# 31     False
# 32      True
# 33      True
# 34      True
# 35      True
# 36      True
# 37      True
# 38      True
# 39     False
# 40     False
# 41     False
# 42      True
# 43      True
# 44      True
# 45     False
# 46      True
# 47      True
# 48      True
# 49      True
# 50      True
# 51     False
# 52      True
# 53      True
# 54      True
# 55      True
# 56      True
# 57      True
# 58      True
# 59      True
# 60      True
# 61      True
# 62     False
# 63      True
# 64      True
# 65      True
# 66      True
# 67      True
# 68      True
# 69      True
# 70      True
# 71      True
# 72      True
# 73      True
# 74      True
# 75      True
# 76      True
# 77      True
# 78     False
# 79     False
# 80      True
# 81      True
# 82      True
# 83      True
# 84      True
# 85     False
# 86      True
# 87      True
# 88      True
# 89      True
# 90      True
# 91      True
# 92      True
# 93      True
# 94      True
# 95      True
# 96      True
# 97      True
# 98      True
# 99      True
# 100    False
# 101     True
# 102     True
# 103     True
# 104     True
# 105     True
# 106     True
# 107     True
# 108     True
# 109     True
# 110     True
# 111     True
# 112     True
# 113     True
# 114     True
# 115     True
# 116     True
# 117     True
# 118     True
# 119    False
# 120     True
# 121     True
# 122     True
# 123     True
# 124     True
# 125     True
# 126     True
# 127     True
# 128     True
# 129     True
# 130     True
# 131     True
# 132     True
# 133     True
# 134     True
# 135     True
# 136     True
# 137     True
# 138     True
# 139     True
# 140     True
# 141     True
# 142     True
# 143     True
# 144     True
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# 150     True
# 151     True
# 152     True
# 153     True
# 154     True
# 155     True
# 156     True
# 157     True
# 158     True
# 159     True
# 160     True
# 161     True
# 162     True
# 163    False
# 164     True
# 165     True
# 166     True
# 167     True
# 168     True
# 169     True
# 170     True
# 171     True
# 172     True
# 173     True
# 174     True
# 175     True
# 176     True
# 177     True
# 178     True
# 179    False
# 180     True
# 181     True
# 182     True
# 183     True
# 184     True
# 185    False
# 186     True
# 187     True
# 188     True
# 189    False
# 190     True
# 191    False
# 192    False
# 193     True
# 194     True
# 195     True
# 196     True
# 197     True
# 198     True
# 199     True
# 200     True
# 201     True
# 202    False
# 203     True
# 204     True
# 205     True
# 206     True
# 207    False
# 208     True
# 209     True
# 210     True
# 211     True
# 212     True
# 213     True
# 214     True
# 215     True
# 216     True
# 217    False
# 218     True
# 219     True
# 220     True
# 221     True
# 222    False
# 223     True
# 224     True
# 225     True
# 226     True
# 227     True
# 228     True
# Name: Client Status, dtype: bool

# %%
#Now I feed the boolean we create above into a new dataframe called 'clients_active'. 
#I can see that there are now 203 rows, which is perfect because I just removed the 26 'Cancelled' clients.
clients_active = discrete_clients[discrete_clients['Client Status'].isin(active_clients)]
clients_active.shape
# Out:
# (203, 10)

# %%
clients_active.describe().round(2)
# Out:
#           Age  Appointments
# count  172.00        203.00
# mean    38.04          2.89
# std     12.04          3.01
# min     15.00          1.00
# 25%     29.75          1.00
# 50%     37.00          1.00
# 75%     46.00          4.00
# max     70.00         18.00

# %%
#And here I just wanted to look at the dataframe. It looks good. Now to address the remaining Nan values.
clients_active
# Out:
#            ID               Problem                     Type Client Status  \
# 0    100kieAl           Personality       Private (Standard)        Active
# 1    101kosPe           Personality       Private (Standard)        Active
# 2    102lanHe         Relationships        Agency (Standard)        Active
# 4    104lanKe         Substance use        Agency (Standard)        Active
# 5    105lasAn         Relationships  Private (complementary)        Active
# 6    106lenAl                Stress  Private (complementary)        Active
# 7    107letJa           Personality  Private (complementary)        Active
# 8    108leyAn               Anxiety       Private (Standard)        Active
# 10    10amsKa           Personality        Agency (Standard)        Active
# 11   110leyDa         Relationships       Private (Standard)        Active
# 13   112lieKa         Relationships  Private (complementary)        Active
# 14   113lieRy           Personality         Inspirit - (WDO)        Active
# 15   114ljaLu                Stress  Private (complementary)        Active
# 16   115lloMa  Obsessive-Compulsive  Private (complementary)        Active
# 17   116llyJa         Relationships       Private (Standard)        Active
# 18   117lmeSi         Relationships        Agency (Standard)        Active
# 19   118losCa               Anxiety  Private (complementary)        Active
# 20   119losJa         Relationships       Private (Standard)        Active
# 22   120manCa         Substance use  Private (complementary)        Active
# 23   121manDa                Autism       Private (Standard)        Active
# 24   122manTa         Relationships               EAP Client        Active
# 25   123marMa         Relationships  Private (complementary)        Active
# 26   124masBe         Relationships             Not Assigned        Active
# 27   125mazSa         Relationships       Private (Standard)        Active
# 28   126mbeSh               Anxiety  Private (complementary)        Active
# 29   127mecSa               Anxiety  Private (complementary)        Active
# 30   128merBr         Relationships       Private (Standard)        Active
# 32    12amsPa         Relationships  Private (complementary)        Active
# 33   130mosSh         Relationships  Private (complementary)        Active
# 34   131nemCa           Supervision              Supervision        Active
# 35   132nerDa         Relationships       Private (Standard)        Active
# 36   133nerTa         Substance use  Private (complementary)        Active
# 37   134nesDo               Anxiety             Not Assigned        Active
# 38   135nesKa               Anxiety               EAP Client        Active
# 42   139neyCh         Mood disorder  Private (complementary)        Active
# 43    13andJo         Relationships               EAP Client        Active
# 44   140nicVe               Anxiety             Not Assigned        Active
# 46   142nisMa                Stress        Agency (Standard)        Active
# 47   143nkiNi         Relationships  Private (complementary)        Active
# 48   144nkoVa         Relationships       Private (Standard)        Active
# 49   145nryAl         Substance use  Private (complementary)        Active
# 50   146ntiTa               Anxiety  Private (complementary)        Active
# 52   148ollMe         Relationships       Private (Standard)        Active
# 53   149ollMe  Obsessive-Compulsive  Private (complementary)        Active
# 54    14andMa               Anxiety       Private (Standard)        Active
# 55   150oneRu               Anxiety  Private (complementary)        Active
# 56   151ongSa               Anxiety       Private (Standard)        Active
# 57   152oodCl         Mood disorder   Agency (complementary)        Active
# 58   153oodMi         Substance use  Private (complementary)        Active
# 59   154ordBe            Adjustment               EAP Client        Active
# 60   155oseDa           Personality       Private (Standard)        Active
# 61   156ottLo                Stress       Private (Standard)        Active
# 63   158ovaEk         Relationships  Private (complementary)        Active
# 64   159oweAm                Stress               EAP Client        Active
# 65    15aneMa                Trauma  Private (complementary)        Active
# 66   160ranZo         Relationships       Private (Standard)        Active
# 67   161raySc         Relationships       Private (Standard)        Active
# 68   162renCh         Relationships       Private (Standard)        Active
# 69   163renPe           Personality               EAP Client        Active
# 70   164resNa         Relationships  Private (complementary)        Active
# 71   165reySu            Adjustment       Private (Standard)        Active
# 72   166rgeKa         Relationships  Private (complementary)        Active
# 73   167ricSt               Anxiety             Not Assigned        Active
# 74   168rieBe         Relationships       Private (Standard)        Active
# 75   169risKi         Relationships               EAP Client        Active
# 76    16angCh         Substance use             Not Assigned        Active
# 77   170risLi               Anxiety  Private (complementary)        Active
# 80   173rpeBe  Obsessive-Compulsive               EAP Client        Active
# 81   174rryDa         Relationships        Agency (Standard)        Active
# 82   175rsiMa           Personality        Agency (Standard)        Active
# 83   176ruzNa         Relationships        Agency (Standard)        Active
# 84   177salRo           Personality               EAP Client        Active
# 86   179skaIv               Anxiety        Agency (Standard)        Active
# 87    17angSe         Relationships        Agency (Standard)        Active
# 88   180skiSa               Anxiety  Private (complementary)        Active
# 89   181sonDa         Mood disorder       Private (Standard)        Active
# 90   182sonEl               Anxiety  Private (complementary)        Active
# 91   183sonJe               Anxiety  Private (complementary)        Active
# 92   184sonJo            Adjustment  Private (complementary)        Active
# 93   185sonLo         Relationships  Private (complementary)        Active
# 94   186sonMa         Relationships  Private (complementary)        Active
# 95   187sonMa         Relationships  Private (complementary)        Active
# 96   188sonSt         Relationships             Not Assigned        Active
# 97   189ssiAn         Mood disorder  Private (complementary)        Active
# 98    18angXu                Stress             Not Assigned        Active
# 99   190tanSe               Anxiety   Agency (complementary)        Active
# 101  192thyCl               Anxiety  Private (complementary)        Active
# 102  193thyLu  Obsessive-Compulsive  Private (complementary)        Active
# 103  194tieSi           Personality               EAP Client        Active
# 104  195tisEf         Relationships             Not Assigned        Active
# 105  196tonAn                Trauma       Private (Standard)        Active
# 106  197tonBe         Relationships  Private (complementary)        Active
# 107  198tonEl         Substance use  Private (complementary)        Active
# 108  199tonHe           Personality  Private (complementary)        Active
# 109   19ansSa           Supervision             Not Assigned        Active
# 110    1achMi  Obsessive-Compulsive       Private (Standard)        Active
# 111  200tonKe            Adjustment       Private (Standard)        Active
# 112  201tonSa           Personality  Private (complementary)        Active
# 113  202uceJu                Stress               EAP Client        Active
# 114  203ummSt                Health  Private (complementary)        Active
# 115  204untRi           Personality  Private (complementary)        Active
# 116  205uryJa               Anxiety               EAP Client        Active
# 117  206useNa         Relationships       Private (Standard)        Active
# 118  207uttSu               Anxiety       Private (Standard)        Active
# 120  209vaiMi               Anxiety  Private (complementary)        Active
# 121   20antLu         Mood disorder      Inspirit (Standard)        Active
# 122  210veyZa                Stress       Private (Standard)        Active
# 123  211vicMa               Anxiety       Private (Standard)        Active
# 124  212visCo               Anxiety       Private (Standard)        Active
# 125  213visGr            Adjustment  Private (complementary)        Active
# 126  214walNi           Personality  Private (complementary)        Active
# 127  215wenJa         Substance use  Private (complementary)        Active
# 128  216wenPa               Anxiety               EAP Client        Active
# 129  217XieAl               Anxiety       Private (Standard)        Active
# 130  218yahTi         Relationships  Private (complementary)        Active
# 131  219zarMe         Relationships  Private (complementary)        Active
# 132   21antPa         Relationships       Private (Standard)        Active
# 133  220zasDa               Anxiety  Private (complementary)        Active
# 134  221eldDa                Stress  Private (complementary)        Active
# 135  222phyDr                Stress  Private (complementary)        Active
# 136  223loeBe                Stress  Private (complementary)        Active
# 137  224kieFi         Relationships  Private (complementary)        Active
# 138  225ikeGa         Relationships  Private (complementary)        Active
# 139  226dasHe               Anxiety  Private (complementary)        Active
# 140  227ockMi         Mood disorder  Private (complementary)        Active
# 141  228allNi         Relationships  Private (complementary)        Active
# 142  229FooSa           Personality  Private (complementary)        Active
# 143   22araLe                Trauma  Private (complementary)        Active
# 144   23ardAd               Anxiety  Private (complementary)        Active
# 145   24ardAl               Anxiety             Not Assigned        Active
# 146   25ardCa               Anxiety  Private (complementary)        Active
# 147   26ardMa         Mood disorder       Private (Standard)        Active
# 148   27ariAn                Stress        Agency (Standard)        Active
# 149   28arrZo         Relationships  Private (complementary)        Active
# 150   29attAn         Mood disorder   Agency (complementary)        Active
# 151    2acsMa                Stress               EAP Client        Active
# 152   30besMa           Personality   Agency (complementary)        Active
# 153   31bleLo                Stress               EAP Client        Active
# 154   32cerCe          Not Assigned  Private (complementary)        Active
# 155   33cicLj                Trauma  Private (complementary)        Active
# 156   34cicNu                Stress        Agency (Standard)        Active
# 157   35ckyJo         Relationships  Private (complementary)        Active
# 158   36CoxAn         Relationships  Private (complementary)        Active
# 159   37CoxAn         Relationships       Private (Standard)        Active
# 160   38delBa         Mood disorder       Private (Standard)        Active
# 161   39delGr           Personality       Private (Standard)        Active
# 162    3ainNa         Substance use       Private (Standard)        Active
# 164   41derSa                Trauma       Private (Standard)        Active
# 165   42dgeLi               Anxiety       Private (Standard)        Active
# 166   43edaSa           Personality       Private (Standard)        Active
# 167   44eerJa  Obsessive-Compulsive       Private (Standard)        Active
# 168   45eidDa                Autism       Private (Standard)        Active
# 169   46eilBr                Stress  Private (complementary)        Active
# 170   47eilSh         Relationships       Private (Standard)        Active
# 171   48eldCh           Personality  Private (complementary)        Active
# 172   49eldNi                Health  Private (complementary)        Active
# 173    4akeCh         Relationships       Private (Standard)        Active
# 174   50eldNi                Health  Private (complementary)        Active
# 175   51ellCa            Adjustment               EAP Client        Active
# 176   52ellIa         Substance use  Private (complementary)        Active
# 177   53ellLu           Personality  Private (complementary)        Active
# 178   54ellSi         Substance use   Agency (complementary)        Active
# 180   56ensJe                Trauma             Not Assigned        Active
# 181   57eonPa           Personality       Private (Standard)        Active
# 182   58ersBe                Trauma   Agency (complementary)        Active
# 183   59ersNi           Personality  Private (complementary)        Active
# 184    5akeMa         Mood disorder       Private (Standard)        Active
# 186   61essCa           Personality  Private (complementary)        Active
# 187   62ettMa           Personality  Private (complementary)        Active
# 188   63fesAn         Relationships       Private (Standard)        Active
# 190   65gorMa         Substance use  Private (complementary)        Active
# 193   68halCr         Relationships             Not Assigned        Active
# 194   69hamAl         Relationships  Private (complementary)        Active
# 195    6aldBr            Adjustment        Agency (Standard)        Active
# 196   70hamGe         Relationships  Private (complementary)        Active
# 197   71hamMo                Trauma             Not Assigned        Active
# 198   72hanCa               Anxiety       Private (Standard)        Active
# 199   73herRy         Substance use  Private (complementary)        Active
# 200   74ianBe           Personality       Private (Standard)        Active
# 201   75iarJo           Personality       Private (Standard)        Active
# 203   77inaMa           Personality        Agency (Standard)        Active
# 204   78ingJo         Substance use   Agency (complementary)        Active
# 205   79ingEl         Relationships       Private (Standard)        Active
# 206    7allBe           Personality       Private (Standard)        Active
# 208   81ingNi         Relationships       Private (Standard)        Active
# 209   82ingPe         Relationships       Private (Standard)        Active
# 210   83ingSa                Stress  Private (complementary)        Active
# 211   84iniMa         Relationships   Agency (complementary)        Active
# 212   85inkSa         Substance use             Not Assigned        Active
# 213   86insDa               Anxiety       Private (Standard)        Active
# 214   87iorNa         Substance use  Private (complementary)        Active
# 215   88iraPh                Stress  Private (complementary)        Active
# 216   89ireJe           Personality       Private (Standard)        Active
# 218   90irkTr                Health  Private (complementary)        Active
# 219   91iseLo               Anxiety       Private (Standard)        Active
# 220   92issJa                Stress  Private (complementary)        Active
# 221   93iteNa         Relationships        Agency (Standard)        Active
# 223   95ithDe         Relationships        Agency (Standard)        Active
# 224   96ithJe               Anxiety  Private (complementary)        Active
# 225   97kerDa          Not Assigned  Private (complementary)        Active
# 226   98kerJu         Substance use       Private (Standard)        Active
# 227   99kerSt               Anxiety  Private (complementary)        Active
# 228    9amsAl         Relationships             Not Assigned        Active
#
#           Gender   Age           Source             Suburb Healing  \
# 0         Female  33.0         Internet              Menai      No
# 1           Male  43.0         Internet         Yarrawarra      No
# 2         Female  33.0           Agency   Woronora Heights      No
# 4         Female  64.0         Internet          Bomaderry      No
# 5           Male   NaN         Internet        Grays Point      No
# 6         Female  25.0    Word of mouth         Woolooware      No
# 7         Female  37.0               GP        Helensburgh      No
# 8           Male  47.0         Internet            Kareela      No
# 10          Male  38.0  Previous client                NaN      No
# 11          Male   NaN           Agency         Sutherland      No
# 13        Female  31.0         Internet        Helensburgh      No
# 14          Male  21.0              WDO   Greenhills Beach      No
# 15          Male  44.0    Word of mouth          Gymea Bay      No
# 16        Female  29.0         Internet         Sutherland     Yes
# 17        Female  53.0         Internet           Sylvania      No
# 18          Male  38.0           Agency               Como      No
# 19        Female  23.0         Internet           Illawong      No
# 20        Female  49.0         Internet  Brighten Le Sands      No
# 22        Female   NaN              NaN                NaN      No
# 23        Female   NaN  Previous client        Camera Park      No
# 24        Female   NaN              EAP            Miranda      No
# 25        Female  36.0        Colleague            Montery      No
# 26        Female  39.0              NaN         Sutherland      No
# 27        Female  36.0        Colleague              Gymea      No
# 28        Female  26.0         Internet          Heathcote     Yes
# 29        Female  22.0         Internet          Caringbah      No
# 30        Female  36.0         Internet              Menai      No
# 32          Male  46.0               GP           Engadine      No
# 33          Male  43.0        Colleague         Manly Vale      No
# 34        Female   NaN              NaN            Lakemba      No
# 35          Male  49.0         Internet           Engadine      No
# 36        Female   NaN         Internet           Cronulla      No
# 37        Female  51.0              NaN           Cronulla      No
# 38        Female   NaN              EAP           Buraneer      No
# 42          Male  31.0         Internet              Gymea      No
# 43        Female   NaN              EAP         Sutherland      No
# 44        Female   NaN              NaN                NaN      No
# 46        Female  59.0           Agency  Brighton Le Sands      No
# 47          Male  27.0              NaN      Alfords Point      No
# 48          Male   NaN              NaN                NaN      No
# 49        Female  21.0               GP              Gymea      No
# 50        Female  25.0    Word of mouth    Sylvania Waters      No
# 52        Female  34.0               GP             Bangor     Yes
# 53        Female  40.0               GP             Bangor     Yes
# 54        Female  28.0         Internet       Barden Ridge      No
# 55          Male  18.0         Internet           Coledale      No
# 56          Male  31.0               GP         Blakehurst      No
# 57          Male  46.0           Agency            Jannali      No
# 58          Male  46.0         Internet              Gymea     Yes
# 59        Female  56.0              EAP       Barden Ridge      No
# 60          Male  35.0         Internet           Sylvania      No
# 61        Female   NaN              NaN                NaN      No
# 63        Female  35.0         Internet        Kogarah Bay      No
# 64        Female   NaN              NaN            Miranda      No
# 65          Male  47.0    Word of mouth          Heathcote      No
# 66        Female  41.0               GP           Kirrawee      No
# 67          Male  53.0         Internet              Gymea      No
# 68          Male  38.0               GP     Connells Point      No
# 69        Female  21.0              NaN          Caringbah      No
# 70        Female  34.0    Word of mouth           Milperra      No
# 71        Female  58.0         Internet            Padstow      No
# 72        Female   NaN              NaN                NaN      No
# 73        Female  29.0         Internet              Menai     Yes
# 74          Male  39.0         Internet   Woronora Heights      No
# 75        Female   NaN              EAP                NaN      No
# 76        Female  60.0              NaN                NaN      No
# 77        Female  38.0        Colleague        Taren Point     Yes
# 80          Male   NaN              EAP         Sutherland      No
# 81        Female  43.0           Agency          Caringbah      No
# 82          Male  31.0           Agency              Gymea      No
# 83        Female  40.0           Agency      Voyager Point      No
# 84        Female  32.0              EAP            Allawah      No
# 86        Female  17.0           Agency          Penshurst      No
# 87        Female  36.0              NaN         Sutherland      No
# 88        Female   NaN         Internet   Woronora Heights     Yes
# 89          Male  55.0               GP             Bangor      No
# 90          Male  28.0               GP              Bulli      No
# 91        Female  24.0    Word of mouth                NaN      No
# 92          Male  37.0         Internet            Padstow     Yes
# 93        Female  43.0         Internet          Worronora     Yes
# 94          Male   NaN         Internet           Engadine      No
# 95          Male  37.0         Internet           Engadine      No
# 96          Male  44.0         Internet            Kareela      No
# 97          Male  28.0         Internet            Jannali      No
# 98          Male  46.0              NaN           Eastwood     Yes
# 99        Female  29.0           Agency               Como      No
# 101       Female  31.0         Internet           Lewisham     Yes
# 102         Male  18.0         Internet           Kirrawee      No
# 103         Male   NaN              EAP        Grays Point     Yes
# 104       Female  53.0              NaN                NaN      No
# 105       Female  60.0         Referral   Woronora Heights      No
# 106         Male  19.0         Internet           Woronora      No
# 107       Female  33.0         Internet           Kirrawee     Yes
# 108       Female  49.0    Word of mouth           Woronora      No
# 109       Female   NaN              NaN                NaN      No
# 110         Male  37.0               GP         Woolooware      No
# 111         Male  38.0               GP          Mangerton     Yes
# 112         Male  19.0         Internet           Kirrawee      No
# 113  Unspecified   NaN              EAP                NaN      No
# 114         Male  65.0         Internet               Como      No
# 115         Male  58.0         Internet           Sylvania      No
# 116       Female   NaN              EAP                NaN     Yes
# 117         Male  31.0         Internet              Menai      No
# 118       Female  70.0         Referral              Menai      No
# 120       Female   NaN               GP       Barden Ridge      No
# 121         Male  39.0         Internet      Alfords Point      No
# 122         Male  26.0         Internet           Woronora      No
# 123       Female  18.0    Word of mouth            Horsley      No
# 124         Male  26.0           Agency             Bangor      No
# 125         Male  33.0         Referral        Helensburgh      No
# 126         Male  33.0         Internet        Helensburgh      No
# 127       Female  31.0         Internet         Sutherland      No
# 128       Female   NaN              EAP          Gymea Bay      No
# 129       Female  21.0         Internet               Como      No
# 130       Female  35.0         Internet             Bangor      No
# 131       Female  38.0        Colleague            Figtree      No
# 132         Male   NaN              NaN                NaN      No
# 133         Male  39.0    Word of mouth               Como      No
# 134       Female  35.0  Previous client           Engadine     Yes
# 135         Male  40.0         Internet          Caringbah     Yes
# 136         Male  38.0              NaN      Alfords Point     Yes
# 137       Female  52.0         Internet         Wollongong     Yes
# 138       Female  36.0         Internet              Menai     Yes
# 139       Female  42.0         Internet         Sutherland     Yes
# 140         Male  62.0               GP         Sutherland     Yes
# 141       Female  35.0         Internet          Caringbah     Yes
# 142       Female  30.0         Referral         Sutherland     Yes
# 143       Female  53.0        Colleague          Roseville     Yes
# 144         Male  46.0               GP              Gymea      No
# 145         Male   NaN              NaN                NaN      No
# 146         Male  26.0         Internet         Sutherland     Yes
# 147         Male  47.0               GP           Illawong      No
# 148       Female  50.0           Agency          Yowie Bay      No
# 149       Female  24.0         Internet           Engadine      No
# 150         Male  37.0         Internet      Kembla Grange      No
# 151         Male  61.0         Internet         Bonnet Bay     Yes
# 152         Male  44.0           Agency      Stanwell Tops     Yes
# 153       Female   NaN              NaN                NaN      No
# 154         Male  43.0         Internet          Caringbah      No
# 155       Female   NaN    Word of mouth          Liverpool      No
# 156       Female  45.0              NaN           Cronulla      No
# 157         Male  42.0              NaN         Oyster Bay      No
# 158         Male  52.0         Internet           Engadine      No
# 159         Male  48.0         Internet           Engadine      No
# 160         Male  33.0         Internet         Sutherland     Yes
# 161         Male  52.0  Previous client            Kareela      No
# 162         Male  43.0         Internet          Caringbah      No
# 164       Female  56.0    Word of mouth          Caringbah      No
# 165         Male  33.0               GP           Engadine      No
# 166       Female  21.0         Referral              Menai      No
# 167         Male  18.0         Internet               Como      No
# 168         Male  47.0         Internet         Sutherland      No
# 169       Female  45.0        Colleague           Bundeena      No
# 170         Male  44.0         Internet           Bundeena      No
# 171       Female  27.0         Internet              Menai      No
# 172       Female  45.0    Word of mouth           Horseley      No
# 173         Male  69.0         Internet           Kirrawee      No
# 174       Female  15.0    Word of mouth           Horseley      No
# 175       Female   NaN              EAP           Engadine      No
# 176         Male  42.0               GP         Oyster Bay      No
# 177         Male  31.0         Internet        Lilli Pilli      No
# 178       Female  27.0           Agency         Sans Souci      No
# 180       Female  52.0              NaN           Cronulla      No
# 181         Male  69.0         Internet             Bangor      No
# 182       Female  64.0           Agency      Beverly Hills     Yes
# 183       Female  43.0           Agency          Caringbah      No
# 184         Male  44.0               GP         Sutherland      No
# 186         Male  47.0         Internet          Caringbah      No
# 187       Female   NaN              NaN                NaN      No
# 188         Male  33.0         Internet       Barden Ridge      No
# 190       Female  45.0              WDO           Engadine     Yes
# 193       Female  37.0              NaN    Caringbah South      No
# 194       Female  33.0         Internet           Sylvania      No
# 195         Male  41.0           Agency            Belambi      No
# 196       Female  25.0         Internet                NaN      No
# 197         Male   NaN              NaN                NaN      No
# 198         Male  19.0         Internet         Sutherland      No
# 199         Male  25.0         Internet           Illawong      No
# 200       Female  30.0         Internet         Sutherland      No
# 201       Female  35.0               GP         Sutherland      No
# 203         Male  36.0           Agency          Caringbah      No
# 204         Male  51.0           Agency             Bangor      No
# 205       Female  43.0         Internet    Caringbah South      No
# 206         Male  28.0         Internet           Cronulla      No
# 208         Male  31.0         Internet           Woronora      No
# 209         Male  35.0         Internet          Caringbah      No
# 210       Female  37.0         Internet      Voyager Point     Yes
# 211       Female  40.0           Agency        West Hoxton      No
# 212         Male  29.0              NaN           Cronulla      No
# 213         Male  19.0         Internet             Oatley      No
# 214         Male  23.0         Internet         Sutherland      No
# 215       Female  21.0         Internet              Gymea     Yes
# 216       Female  21.0         Internet           Engadine      No
# 218         Male  49.0               GP            Carlton      No
# 219       Female  20.0         Internet             Bangor      No
# 220       Female  39.0         Internet          San Souci      No
# 221       Female  32.0           Agency            Padstow      No
# 223       Female  51.0              NaN        Helensburgh      No
# 224       Female  25.0         Internet               Como     Yes
# 225         Male  50.0         Internet           Cronulla      No
# 226         Male  38.0         Internet     Mount Warrigal      No
# 227         Male  45.0         Internet               Como      No
# 228       Female  30.0        Colleague          Gymea Bay      No
#
#      Appointments
# 0             1.0
# 1             7.0
# 2            11.0
# 4             1.0
# 5             2.0
# 6             1.0
# 7             5.0
# 8             2.0
# 10            4.0
# 11            1.0
# 13            1.0
# 14            1.0
# 15            1.0
# 16           11.0
# 17            1.0
# 18            6.0
# 19            1.0
# 20           18.0
# 22            1.0
# 23            2.0
# 24            4.0
# 25            1.0
# 26            1.0
# 27            1.0
# 28            7.0
# 29            1.0
# 30            2.0
# 32            1.0
# 33            1.0
# 34            1.0
# 35            1.0
# 36            1.0
# 37            1.0
# 38            2.0
# 42            4.0
# 43            5.0
# 44            1.0
# 46            1.0
# 47            2.0
# 48            1.0
# 49            1.0
# 50            1.0
# 52            3.0
# 53            3.0
# 54            1.0
# 55            1.0
# 56            5.0
# 57            2.0
# 58            4.0
# 59            3.0
# 60            3.0
# 61            1.0
# 63            1.0
# 64            1.0
# 65            6.0
# 66            1.0
# 67            6.0
# 68            1.0
# 69            1.0
# 70            2.0
# 71            5.0
# 72            1.0
# 73            5.0
# 74            1.0
# 75            3.0
# 76            1.0
# 77            2.0
# 80            5.0
# 81            2.0
# 82           12.0
# 83            2.0
# 84            1.0
# 86            1.0
# 87            1.0
# 88            5.0
# 89            2.0
# 90            1.0
# 91            3.0
# 92            6.0
# 93            5.0
# 94            2.0
# 95            2.0
# 96            1.0
# 97            1.0
# 98            1.0
# 99            3.0
# 101           2.0
# 102           1.0
# 103           2.0
# 104           1.0
# 105           1.0
# 106           3.0
# 107           2.0
# 108           3.0
# 109           2.0
# 110           1.0
# 111           9.0
# 112           2.0
# 113           3.0
# 114           1.0
# 115           1.0
# 116           4.0
# 117           1.0
# 118           1.0
# 120           1.0
# 121           4.0
# 122           1.0
# 123           1.0
# 124           1.0
# 125           2.0
# 126           5.0
# 127           2.0
# 128           1.0
# 129           1.0
# 130           2.0
# 131           9.0
# 132           1.0
# 133           2.0
# 134           6.0
# 135           8.0
# 136           4.0
# 137           2.0
# 138           2.0
# 139           7.0
# 140          11.0
# 141           1.0
# 142           7.0
# 143           3.0
# 144           1.0
# 145           1.0
# 146           2.0
# 147           4.0
# 148           1.0
# 149           1.0
# 150           1.0
# 151           5.0
# 152           1.0
# 153           1.0
# 154           1.0
# 155           7.0
# 156           4.0
# 157           1.0
# 158           5.0
# 159           5.0
# 160          16.0
# 161           4.0
# 162           1.0
# 164           3.0
# 165           1.0
# 166           1.0
# 167           2.0
# 168           1.0
# 169           1.0
# 170           7.0
# 171           5.0
# 172           8.0
# 173           3.0
# 174           8.0
# 175           3.0
# 176           1.0
# 177           1.0
# 178           1.0
# 180           1.0
# 181           1.0
# 182          17.0
# 183           4.0
# 184           3.0
# 186           1.0
# 187           1.0
# 188           1.0
# 190           6.0
# 193           1.0
# 194           1.0
# 195           1.0
# 196           1.0
# 197           1.0
# 198           9.0
# 199           1.0
# 200           1.0
# 201           1.0
# 203           4.0
# 204          10.0
# 205           1.0
# 206           1.0
# 208           1.0
# 209           4.0
# 210           1.0
# 211           1.0
# 212           1.0
# 213           2.0
# 214           1.0
# 215           6.0
# 216          12.0
# 218           1.0
# 219           3.0
# 220           1.0
# 221           3.0
# 223           1.0
# 224           4.0
# 225           1.0
# 226           3.0
# 227           1.0
# 228           1.0

# %%
#Where are the missing values now?
clients_active.isnull().sum()
# Out:
# ID                0
# Problem           0
# Type              0
# Client Status     0
# Gender            0
# Age              31
# Source           28
# Suburb           19
# Healing           0
# Appointments      0
# dtype: int64

# %% [markdown]
# # Q2) What is the average age of clients?

# %%
#what is the shape of the distribution of Age
clients_active['Age'].plot.hist(alpha=0.5)

# %%
Age = clients_active['Age']
sns.distplot(Age);

# %%
mean_age = Age.mean()
print('Mean of clients = ' + str(round(mean_age,2)))
# Out:
# Mean of clients = 38.04

# %% [markdown]
# ### From August 2019 to March 2020 the mean age of clients was 38 years.

# %% [markdown]
# ### Replacing missing age data with the sample mean
# I was curious about what effect replacing the missing age values with mean age would have on the distribution.

# %%
modified = clients_active['Age'].replace(to_replace = np.nan, value = mean_age) 
modified
# Out:
# 0      33.000000
# 1      43.000000
# 2      33.000000
# 4      64.000000
# 5      38.040698
# 6      25.000000
# 7      37.000000
# 8      47.000000
# 10     38.000000
# 11     38.040698
# 13     31.000000
# 14     21.000000
# 15     44.000000
# 16     29.000000
# 17     53.000000
# 18     38.000000
# 19     23.000000
# 20     49.000000
# 22     38.040698
# 23     38.040698
# 24     38.040698
# 25     36.000000
# 26     39.000000
# 27     36.000000
# 28     26.000000
# 29     22.000000
# 30     36.000000
# 32     46.000000
# 33     43.000000
# 34     38.040698
# 35     49.000000
# 36     38.040698
# 37     51.000000
# 38     38.040698
# 42     31.000000
# 43     38.040698
# 44     38.040698
# 46     59.000000
# 47     27.000000
# 48     38.040698
# 49     21.000000
# 50     25.000000
# 52     34.000000
# 53     40.000000
# 54     28.000000
# 55     18.000000
# 56     31.000000
# 57     46.000000
# 58     46.000000
# 59     56.000000
# 60     35.000000
# 61     38.040698
# 63     35.000000
# 64     38.040698
# 65     47.000000
# 66     41.000000
# 67     53.000000
# 68     38.000000
# 69     21.000000
# 70     34.000000
# 71     58.000000
# 72     38.040698
# 73     29.000000
# 74     39.000000
# 75     38.040698
# 76     60.000000
# 77     38.000000
# 80     38.040698
# 81     43.000000
# 82     31.000000
# 83     40.000000
# 84     32.000000
# 86     17.000000
# 87     36.000000
# 88     38.040698
# 89     55.000000
# 90     28.000000
# 91     24.000000
# 92     37.000000
# 93     43.000000
# 94     38.040698
# 95     37.000000
# 96     44.000000
# 97     28.000000
# 98     46.000000
# 99     29.000000
# 101    31.000000
# 102    18.000000
# 103    38.040698
# 104    53.000000
# 105    60.000000
# 106    19.000000
# 107    33.000000
# 108    49.000000
# 109    38.040698
# 110    37.000000
# 111    38.000000
# 112    19.000000
# 113    38.040698
# 114    65.000000
# 115    58.000000
# 116    38.040698
# 117    31.000000
# 118    70.000000
# 120    38.040698
# 121    39.000000
# 122    26.000000
# 123    18.000000
# 124    26.000000
# 125    33.000000
# 126    33.000000
# 127    31.000000
# 128    38.040698
# 129    21.000000
# 130    35.000000
# 131    38.000000
# 132    38.040698
# 133    39.000000
# 134    35.000000
# 135    40.000000
# 136    38.000000
# 137    52.000000
# 138    36.000000
# 139    42.000000
# 140    62.000000
# 141    35.000000
# 142    30.000000
# 143    53.000000
# 144    46.000000
# 145    38.040698
# 146    26.000000
# 147    47.000000
# 148    50.000000
# 149    24.000000
# 150    37.000000
# 151    61.000000
# 152    44.000000
# 153    38.040698
# 154    43.000000
# 155    38.040698
# 156    45.000000
# 157    42.000000
# 158    52.000000
# 159    48.000000
# 160    33.000000
# 161    52.000000
# 162    43.000000
# 164    56.000000
# 165    33.000000
# 166    21.000000
# 167    18.000000
# 168    47.000000
# 169    45.000000
# 170    44.000000
# 171    27.000000
# 172    45.000000
# 173    69.000000
# 174    15.000000
# 175    38.040698
# 176    42.000000
# 177    31.000000
# 178    27.000000
# 180    52.000000
# 181    69.000000
# 182    64.000000
# 183    43.000000
# 184    44.000000
# 186    47.000000
# 187    38.040698
# 188    33.000000
# 190    45.000000
# 193    37.000000
# 194    33.000000
# 195    41.000000
# 196    25.000000
# 197    38.040698
# 198    19.000000
# 199    25.000000
# 200    30.000000
# 201    35.000000
# 203    36.000000
# 204    51.000000
# 205    43.000000
# 206    28.000000
# 208    31.000000
# 209    35.000000
# 210    37.000000
# 211    40.000000
# 212    29.000000
# 213    19.000000
# 214    23.000000
# 215    21.000000
# 216    21.000000
# 218    49.000000
# 219    20.000000
# 220    39.000000
# 221    32.000000
# 223    51.000000
# 224    25.000000
# 225    50.000000
# 226    38.000000
# 227    45.000000
# 228    30.000000
# Name: Age, dtype: float64

# %%
#I replace missing ages with mean age but I do not like the look of the distribution. 
# There is an excessive peak at 38 years which is making it leptokurtic.
sns.distplot(modified)

# %%
print(Age.describe())
# Out:
# count    172.000000
# mean      38.040698
# std       12.042982
# min       15.000000
# 25%       29.750000
# 50%       37.000000
# 75%       46.000000
# max       70.000000
# Name: Age, dtype: float64

# %%
clients_active.boxplot('Age')

# %% [markdown]
# ### Is there a difference in mean age between those clients receiving energy medicine and those that do not?

# %%
#Now lets see how Age might differ between those receiving energy medicine and those without.
Age_diff_healed=clients_active.groupby('Healing').Age.mean()
Age_diff_healed.round(2).astype(str)
# Out:
# Healing
# No     37.81
# Yes    39.03
# Name: Age, dtype: object

# %%
Age_diff_healed.plot.bar()

# %%
Age_energy=clients_active.groupby('Healing')
Age_energy.describe()
# Out:
#            Age                                                        \
#          count       mean        std   min    25%   50%    75%   max
# Healing
# No       140.0  37.814286  12.355982  15.0  28.75  37.0  46.00  70.0
# Yes       32.0  39.031250  10.687600  21.0  32.50  37.5  44.25  64.0
#
#         Appointments
#                count      mean       std  min  25%  50%  75%   max
# Healing
# No             168.0  2.416667  2.565120  1.0  1.0  1.0  3.0  18.0
# Yes             35.0  5.142857  3.911844  1.0  2.0  4.0  6.5  17.0

# %% [markdown]
# There is a narrower distribution of ages in the Healing group but the mean age is similar.

# %% [markdown]
# ## Q3). What age should marketing target for energy healing clients?
# People aged 32 to 44 years.

# %% [markdown]
# ### As a bonus I have identified those clients with missing 'Age' so I can update my files.

# %%
#Here is the data for clients with missing Age
clients_active[clients_active['Age'].isnull()]
# Out:
#            ID               Problem                     Type Client Status  \
# 5    105lasAn         Relationships  Private (complementary)        Active
# 11   110leyDa         Relationships       Private (Standard)        Active
# 22   120manCa         Substance use  Private (complementary)        Active
# 23   121manDa                Autism       Private (Standard)        Active
# 24   122manTa         Relationships               EAP Client        Active
# 34   131nemCa           Supervision              Supervision        Active
# 36   133nerTa         Substance use  Private (complementary)        Active
# 38   135nesKa               Anxiety               EAP Client        Active
# 43    13andJo         Relationships               EAP Client        Active
# 44   140nicVe               Anxiety             Not Assigned        Active
# 48   144nkoVa         Relationships       Private (Standard)        Active
# 61   156ottLo                Stress       Private (Standard)        Active
# 64   159oweAm                Stress               EAP Client        Active
# 72   166rgeKa         Relationships  Private (complementary)        Active
# 75   169risKi         Relationships               EAP Client        Active
# 80   173rpeBe  Obsessive-Compulsive               EAP Client        Active
# 88   180skiSa               Anxiety  Private (complementary)        Active
# 94   186sonMa         Relationships  Private (complementary)        Active
# 103  194tieSi           Personality               EAP Client        Active
# 109   19ansSa           Supervision             Not Assigned        Active
# 113  202uceJu                Stress               EAP Client        Active
# 116  205uryJa               Anxiety               EAP Client        Active
# 120  209vaiMi               Anxiety  Private (complementary)        Active
# 128  216wenPa               Anxiety               EAP Client        Active
# 132   21antPa         Relationships       Private (Standard)        Active
# 145   24ardAl               Anxiety             Not Assigned        Active
# 153   31bleLo                Stress               EAP Client        Active
# 155   33cicLj                Trauma  Private (complementary)        Active
# 175   51ellCa            Adjustment               EAP Client        Active
# 187   62ettMa           Personality  Private (complementary)        Active
# 197   71hamMo                Trauma             Not Assigned        Active
#
#           Gender  Age           Source            Suburb Healing  Appointments
# 5           Male  NaN         Internet       Grays Point      No           2.0
# 11          Male  NaN           Agency        Sutherland      No           1.0
# 22        Female  NaN              NaN               NaN      No           1.0
# 23        Female  NaN  Previous client       Camera Park      No           2.0
# 24        Female  NaN              EAP           Miranda      No           4.0
# 34        Female  NaN              NaN           Lakemba      No           1.0
# 36        Female  NaN         Internet          Cronulla      No           1.0
# 38        Female  NaN              EAP          Buraneer      No           2.0
# 43        Female  NaN              EAP        Sutherland      No           5.0
# 44        Female  NaN              NaN               NaN      No           1.0
# 48          Male  NaN              NaN               NaN      No           1.0
# 61        Female  NaN              NaN               NaN      No           1.0
# 64        Female  NaN              NaN           Miranda      No           1.0
# 72        Female  NaN              NaN               NaN      No           1.0
# 75        Female  NaN              EAP               NaN      No           3.0
# 80          Male  NaN              EAP        Sutherland      No           5.0
# 88        Female  NaN         Internet  Woronora Heights     Yes           5.0
# 94          Male  NaN         Internet          Engadine      No           2.0
# 103         Male  NaN              EAP       Grays Point     Yes           2.0
# 109       Female  NaN              NaN               NaN      No           2.0
# 113  Unspecified  NaN              EAP               NaN      No           3.0
# 116       Female  NaN              EAP               NaN     Yes           4.0
# 120       Female  NaN               GP      Barden Ridge      No           1.0
# 128       Female  NaN              EAP         Gymea Bay      No           1.0
# 132         Male  NaN              NaN               NaN      No           1.0
# 145         Male  NaN              NaN               NaN      No           1.0
# 153       Female  NaN              NaN               NaN      No           1.0
# 155       Female  NaN    Word of mouth         Liverpool      No           7.0
# 175       Female  NaN              EAP          Engadine      No           3.0
# 187       Female  NaN              NaN               NaN      No           1.0
# 197         Male  NaN              NaN               NaN      No           1.0

# %%
#Here are just the names of clients with missing Age
clients_no_age = clients_active.ID[clients_active['Age'].isnull()]
print(clients_no_age)
# Out:
# 5      105lasAn
# 11     110leyDa
# 22     120manCa
# 23     121manDa
# 24     122manTa
# 34     131nemCa
# 36     133nerTa
# 38     135nesKa
# 43      13andJo
# 44     140nicVe
# 48     144nkoVa
# 61     156ottLo
# 64     159oweAm
# 72     166rgeKa
# 75     169risKi
# 80     173rpeBe
# 88     180skiSa
# 94     186sonMa
# 103    194tieSi
# 109     19ansSa
# 113    202uceJu
# 116    205uryJa
# 120    209vaiMi
# 128    216wenPa
# 132     21antPa
# 145     24ardAl
# 153     31bleLo
# 155     33cicLj
# 175     51ellCa
# 187     62ettMa
# 197     71hamMo
# Name: ID, dtype: object

# %% [markdown]
# # Q4) What is the gender split of clients for the whole sample?

# %%
denom = client['Gender'].count()
client.groupby(['Gender'])['Gender'].count()*100/denom
# Out:
# Gender
# Female         53.694581
# Male           45.812808
# Unspecified     0.492611
# Name: Gender, dtype: float64

# %% [markdown]
# #### The gender split is 54% Females and 46% males.

# %% [markdown]
# ## What is the gender split of standard and healing clients?

# %%
#I used SQL to create a new dataframe that contains only clients who did not receive the energy medicine treatment.
import sqlite3
from pandas.io import sql
clients = pd.read_csv('clients_active.csv')

# %%
db_connection = sqlite3.connect('clients.db.sqlite')
clients.to_sql('clients', db_connection)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\pandas\core\generic.py:2663: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
query = """
    SELECT *
    FROM clients
    WHERE Healing = "No";
    """
normal_clients = sql.read_sql(query, con=db_connection)

# %%
#Calculating percentages of gender for standard clients
Total_Gender = normal_clients['Gender'].count()
males = normal_clients.Gender[normal_clients.Gender == "Male"]
male_count = males.count()
Percentage_male = male_count*100/Total_Gender
females = normal_clients.Gender[normal_clients.Gender == "Female"]
female_count = females.count()
Percentage_female = female_count*100/Total_Gender

Percentage_male.round(2).astype(str) + '%', Percentage_female.round(2).astype(str) + '%'
# Out:
# ('48.21%', '51.19%')

# %% [markdown]
# #### So for clients who did not receive the healing service 48% were males and 51% were females.

# %% [markdown]
# #### Now I need to do the same for clients who did receive the energy medicine treatment. What is the percentage split for them?

# %%
# This time I want to create a datafram only for those who received the energy medicine but I want to do it with pandas.
Energy_clients = clients[clients.Healing == "Yes"]
Energy_clients
# Out:
#            ID               Problem                     Type Client Status  \
# 13   115lloMa  Obsessive-Compulsive  Private (complementary)        Active
# 24   126mbeSh               Anxiety  Private (complementary)        Active
# 42   148ollMe         Relationships       Private (Standard)        Active
# 43   149ollMe  Obsessive-Compulsive  Private (complementary)        Active
# 48   153oodMi         Substance use  Private (complementary)        Active
# 62   167ricSt               Anxiety             Not Assigned        Active
# 66   170risLi               Anxiety  Private (complementary)        Active
# 74   180skiSa               Anxiety  Private (complementary)        Active
# 78   184sonJo            Adjustment  Private (complementary)        Active
# 79   185sonLo         Relationships  Private (complementary)        Active
# 84    18angXu                Stress             Not Assigned        Active
# 86   192thyCl               Anxiety  Private (complementary)        Active
# 88   194tieSi           Personality               EAP Client        Active
# 92   198tonEl         Substance use  Private (complementary)        Active
# 96   200tonKe            Adjustment       Private (Standard)        Active
# 101  205uryJa               Anxiety               EAP Client        Active
# 118  221eldDa                Stress  Private (complementary)        Active
# 119  222phyDr                Stress  Private (complementary)        Active
# 120  223loeBe                Stress  Private (complementary)        Active
# 121  224kieFi         Relationships  Private (complementary)        Active
# 122  225ikeGa         Relationships  Private (complementary)        Active
# 123  226dasHe               Anxiety  Private (complementary)        Active
# 124  227ockMi         Mood disorder  Private (complementary)        Active
# 125  228allNi         Relationships  Private (complementary)        Active
# 126  229FooSa           Personality  Private (complementary)        Active
# 127   22araLe                Trauma  Private (complementary)        Active
# 130   25ardCa               Anxiety  Private (complementary)        Active
# 135    2acsMa                Stress               EAP Client        Active
# 136   30besMa           Personality   Agency (complementary)        Active
# 144   38delBa         Mood disorder       Private (Standard)        Active
# 164   58ersBe                Trauma   Agency (complementary)        Active
# 170   65gorMa         Substance use  Private (complementary)        Active
# 186   83ingSa                Stress  Private (complementary)        Active
# 191   88iraPh                Stress  Private (complementary)        Active
# 198   96ithJe               Anxiety  Private (complementary)        Active
#
#      Gender   Age           Source            Suburb Healing  Appointments
# 13   Female  29.0         Internet        Sutherland     Yes          11.0
# 24   Female  26.0         Internet         Heathcote     Yes           7.0
# 42   Female  34.0               GP            Bangor     Yes           3.0
# 43   Female  40.0               GP            Bangor     Yes           3.0
# 48     Male  46.0         Internet             Gymea     Yes           4.0
# 62   Female  29.0         Internet             Menai     Yes           5.0
# 66   Female  38.0        Colleague       Taren Point     Yes           2.0
# 74   Female   NaN         Internet  Woronora Heights     Yes           5.0
# 78     Male  37.0         Internet           Padstow     Yes           6.0
# 79   Female  43.0         Internet         Worronora     Yes           5.0
# 84     Male  46.0              NaN          Eastwood     Yes           1.0
# 86   Female  31.0         Internet          Lewisham     Yes           2.0
# 88     Male   NaN              EAP       Grays Point     Yes           2.0
# 92   Female  33.0         Internet          Kirrawee     Yes           2.0
# 96     Male  38.0               GP         Mangerton     Yes           9.0
# 101  Female   NaN              EAP               NaN     Yes           4.0
# 118  Female  35.0  Previous client          Engadine     Yes           6.0
# 119    Male  40.0         Internet         Caringbah     Yes           8.0
# 120    Male  38.0              NaN     Alfords Point     Yes           4.0
# 121  Female  52.0         Internet        Wollongong     Yes           2.0
# 122  Female  36.0         Internet             Menai     Yes           2.0
# 123  Female  42.0         Internet        Sutherland     Yes           7.0
# 124    Male  62.0               GP        Sutherland     Yes          11.0
# 125  Female  35.0         Internet         Caringbah     Yes           1.0
# 126  Female  30.0         Referral        Sutherland     Yes           7.0
# 127  Female  53.0        Colleague         Roseville     Yes           3.0
# 130    Male  26.0         Internet        Sutherland     Yes           2.0
# 135    Male  61.0         Internet        Bonnet Bay     Yes           5.0
# 136    Male  44.0           Agency     Stanwell Tops     Yes           1.0
# 144    Male  33.0         Internet        Sutherland     Yes          16.0
# 164  Female  64.0           Agency     Beverly Hills     Yes          17.0
# 170  Female  45.0              WDO          Engadine     Yes           6.0
# 186  Female  37.0         Internet     Voyager Point     Yes           1.0
# 191  Female  21.0         Internet             Gymea     Yes           6.0
# 198  Female  25.0         Internet              Como     Yes           4.0

# %%
#I am calculating the total number of genders here for those who did receive healing and this will be the denominator.
Total_Gender_Energy = Energy_clients['Gender'].count()
Total_Gender_Energy.round(2).astype(str) + '%'
# Out:
# '35%'

# %%
#Now I am doing the same proceedure as above but will streamline the code even more.
#(I watched this tutorial https://www.youtube.com/watch?v=2AFGPdNn4FM&t=7s)
males_energy = Energy_clients.Gender[Energy_clients.Gender == "Male"]
male_energy_count = males_energy.count()
Percentage_male_energy = male_energy_count*100/Total_Gender_Energy
Percentage_male_energy.round(2).astype(str) + '%'
# Out:
# '34.29%'

# %%
#Now I am doing the same proceedure for females.
#(I watched this tutorial https://www.youtube.com/watch?v=2AFGPdNn4FM&t=7s)
females_energy = Energy_clients.Gender[Energy_clients.Gender == "Female"]
female_energy_count = females_energy.count()
Percentage_female_energy = female_energy_count*100/Total_Gender_Energy
Percentage_female_energy.round(2).astype(str) + '%'
# Out:
# '65.71%'

# %%
print('Standard Clients')
print('Percentage females = '+str(Percentage_female))
print('Percentage males = '+str(Percentage_male))
print()
print('Energy Medicine Clients')
print('Percentage females = '+str(Percentage_female_energy))
print('Percentage males = '+str(Percentage_male_energy))
# Out:
# Standard Clients
# Percentage females = 51.19047619047619
# Percentage males = 48.214285714285715
#
# Energy Medicine Clients
# Percentage females = 65.71428571428571
# Percentage males = 34.285714285714285

# %% [markdown]
# #### There is a gender difference between standard clients and energy medicine clients. More females are interested in energy medicine than males.
#
# #### Problem - I need to create percentage columns and then feed them into a group by bar chart. I can do it with counts but don't know how to do it as a percentage.

# %%
client.groupby(['Gender','Healing'])['Gender'].count().unstack('Healing').plot.bar()

# %%
sns.countplot(data=clients,x='Gender',hue='Healing')

# %% [markdown]
# ### Q6) What is the most common issue people seek support for?

# %%
plt.figure(figsize = (20,5))
sns.countplot(data=client,x='Problem')

# %% [markdown]
# ### Q7) What are the top 3 suburbs to target with the marketing?

# %%
status_suburb = client['Suburb']
counts = status_suburb.value_counts()
percent100 = status_suburb.value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
Suburb_percentage = pd.DataFrame({'counts': counts, '%': percent100})
Suburb_percentage
# Out:
#                    counts     %
# Sutherland             18  9.8%
# Caringbah              12  6.5%
# Engadine               12  6.5%
# Gymea                   8  4.3%
# Menai                   8  4.3%
# Como                    8  4.3%
# Bangor                  8  4.3%
# Cronulla                7  3.8%
# Kirrawee                5  2.7%
# Helensburgh             5  2.7%
# Barden Ridge            4  2.2%
# Woronora Heights        4  2.2%
# Woronora                4  2.2%
# Sylvania                4  2.2%
# Kareela                 3  1.6%
# Alfords Point           3  1.6%
# Padstow                 3  1.6%
# Gymea Bay               3  1.6%
# Illawong                3  1.6%
# Grays Point             2  1.1%
# Bundeena                2  1.1%
# Voyager Point           2  1.1%
# Heathcote               2  1.1%
# Horseley                2  1.1%
# Woolooware              2  1.1%
# Caringbah South         2  1.1%
# Oyster Bay              2  1.1%
# Jannali                 2  1.1%
# Miranda                 2  1.1%
# Mangerton               1  0.5%
# Blakehurst              1  0.5%
# Oatley                  1  0.5%
# Sylvania Waters         1  0.5%
# Camera Park             1  0.5%
# Worronora               1  0.5%
# Roseville               1  0.5%
# Lewisham                1  0.5%
# West Hoxton             1  0.5%
# Yowie Bay               1  0.5%
# Figtree                 1  0.5%
# Penshurst               1  0.5%
# Bulli                   1  0.5%
# Stanwell Tops           1  0.5%
# Kembla Grange           1  0.5%
# Allawah                 1  0.5%
# Sans Souci              1  0.5%
# Connells Point          1  0.5%
# Taren Point             1  0.5%
# Brighten Le Sands       1  0.5%
# Montery                 1  0.5%
# Yarrawarra              1  0.5%
# Horsley                 1  0.5%
# Wollongong              1  0.5%
# Eastwood                1  0.5%
# Milperra                1  0.5%
# Buraneer                1  0.5%
# Lilli Pilli             1  0.5%
# Manly Vale              1  0.5%
# Beverly Hills           1  0.5%
# Bonnet Bay              1  0.5%
# Coledale                1  0.5%
# Greenhills Beach        1  0.5%
# Bomaderry               1  0.5%
# Lakemba                 1  0.5%
# Carlton                 1  0.5%
# Liverpool               1  0.5%
# Brighton Le Sands       1  0.5%
# Kogarah Bay             1  0.5%
# Belambi                 1  0.5%
# San Souci               1  0.5%
# Mount Warrigal          1  0.5%

# %%
plt.figure(figsize = (15,5))
sns.countplot(data=clients,x='Suburb')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Conclusions
#
# For the period 19/08/19 to 06/03/20:
#
# 1) What percentage of clients do not attend their first session?
#     - 11.4% of clients do not attend their first session.
#
# 2) What is the average age of clients?
#     - The average age is 38 years
#
# 3) What age should marketing target for energy healing clients?
#     - Marketing should target people aged 32 to 44 years.
#     - For more precise marketing it should be females aged 32 to 44 years.
#
# 4) What is the gender split of clients?
#     - For the total sample it is 54% females and 46% males.
#     - For standard clients the split is 48% males and 51% females.
#     - For the energy medicine clients it is 34% males and 66% females.
#
# 5) What is the average number of appointments per client?
#     - The number of appointments for a client is 2.89 but there is a wide distribution ranging from 1 to 18.
#     - Standard clients will have on average 2.41 appointments.
#     - Energy medicine clients will have an average of 5.14 appointments.
#
# 6) What is the most common issue people seek support for?
#     - Relationship problems, anxiety and personality issues.
#
# 7) What are the top 3 suburbs to target with the marketing?
#     - Sutherland, Caringbah, Engadine
